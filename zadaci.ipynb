# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\User\Desktop\26_11\letovi.csv')
print(df)

new = df['Prices'].str.split(" ", n=1,expand = True)
df["Cijena"]= new[0]
df["Valuta"] = new[1]
df.drop(columns=['Prices'],inplace = True)
df


df["Valuta"].replace({"kn": "eur"}, inplace=True)
df.rename(columns={'Departure date:': 'Departure_date','Date of Arrival:':'Date_of_arrival'}, inplace = True)
df
# Out:
#     Unnamed: 0     Destination     Prices Departure date: Date of Arrival:  \
# 0            0        Valletta     180 kn       Sat 4 Dec        Sat 4 Dec
# 1            1          Paphos     211 kn       Sat 4 Dec        Mon 6 Dec
# 2            2         Tallinn     300 kn       Sat 4 Dec       Sun 12 Dec
# 3            3        Brussels     173 kn       Sun 5 Dec        Wed 8 Dec
# 4            4      Manchester     180 kn       Sun 5 Dec        Sun 5 Dec
# 5            5      Banja Luka     225 kn       Sun 5 Dec        Mon 6 Dec
# 6            6          Málaga     255 kn       Sun 5 Dec        Wed 8 Dec
# 7            7           Paris     278 kn       Sun 5 Dec        Wed 8 Dec
# 8            8      Bratislava     301 kn       Sun 5 Dec       Sun 12 Dec
# 9            9          Douala  10.465 kn       Sun 5 Dec        Mon 3 Jan
# 10          10      Gothenburg     203 kn       Mon 6 Dec        Wed 8 Dec
# ...
